# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path = "/home/mds/Desktop/highway_episodic/result/result_2024-01-29_21:45:43.939257.csv"
result = pd.read_csv(path)
result = result.drop(result.columns[0], axis=1)
result.reset_index()
result.plot(x='episode',y='total_reward')
# Out:
# <Axes: xlabel='episode'>
